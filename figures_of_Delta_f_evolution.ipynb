# %%
from ipynb.fs.full.all_functions_for_Mij_and_Delta_f import *

# %%
from matplotlib.font_manager import FontProperties
from adjustText import adjust_text
import seaborn as sns
from matplotlib import ticker
from matplotlib import rc
from matplotlib import gridspec as gspec
from matplotlib.colors import ListedColormap
from cycler import cycler
mpl.rcParams['figure.dpi']= 190
plt.rcParams["font.family"] = "Times New Roman"
mpl.rcParams['text.usetex'] = True
# turbo_colormap_data = [[0.18995,0.07176,0.23217],[0.19483,0.08339,0.26149],[0.19956,0.09498,0.29024],[0.20415,0.10652,0.31844],[0.20860,0.11802,0.34607],[0.21291,0.12947,0.37314],[0.21708,0.14087,0.39964],[0.22111,0.15223,0.42558],[0.22500,0.16354,0.45096],[0.22875,0.17481,0.47578],[0.23236,0.18603,0.50004],[0.23582,0.19720,0.52373],[0.23915,0.20833,0.54686],[0.24234,0.21941,0.56942],[0.24539,0.23044,0.59142],[0.24830,0.24143,0.61286],[0.25107,0.25237,0.63374],[0.25369,0.26327,0.65406],[0.25618,0.27412,0.67381],[0.25853,0.28492,0.69300],[0.26074,0.29568,0.71162],[0.26280,0.30639,0.72968],[0.26473,0.31706,0.74718],[0.26652,0.32768,0.76412],[0.26816,0.33825,0.78050],[0.26967,0.34878,0.79631],[0.27103,0.35926,0.81156],[0.27226,0.36970,0.82624],[0.27334,0.38008,0.84037],[0.27429,0.39043,0.85393],[0.27509,0.40072,0.86692],[0.27576,0.41097,0.87936],[0.27628,0.42118,0.89123],[0.27667,0.43134,0.90254],[0.27691,0.44145,0.91328],[0.27701,0.45152,0.92347],[0.27698,0.46153,0.93309],[0.27680,0.47151,0.94214],[0.27648,0.48144,0.95064],[0.27603,0.49132,0.95857],[0.27543,0.50115,0.96594],[0.27469,0.51094,0.97275],[0.27381,0.52069,0.97899],[0.27273,0.53040,0.98461],[0.27106,0.54015,0.98930],[0.26878,0.54995,0.99303],[0.26592,0.55979,0.99583],[0.26252,0.56967,0.99773],[0.25862,0.57958,0.99876],[0.25425,0.58950,0.99896],[0.24946,0.59943,0.99835],[0.24427,0.60937,0.99697],[0.23874,0.61931,0.99485],[0.23288,0.62923,0.99202],[0.22676,0.63913,0.98851],[0.22039,0.64901,0.98436],[0.21382,0.65886,0.97959],[0.20708,0.66866,0.97423],[0.20021,0.67842,0.96833],[0.19326,0.68812,0.96190],[0.18625,0.69775,0.95498],[0.17923,0.70732,0.94761],[0.17223,0.71680,0.93981],[0.16529,0.72620,0.93161],[0.15844,0.73551,0.92305],[0.15173,0.74472,0.91416],[0.14519,0.75381,0.90496],[0.13886,0.76279,0.89550],[0.13278,0.77165,0.88580],[0.12698,0.78037,0.87590],[0.12151,0.78896,0.86581],[0.11639,0.79740,0.85559],[0.11167,0.80569,0.84525],[0.10738,0.81381,0.83484],[0.10357,0.82177,0.82437],[0.10026,0.82955,0.81389],[0.09750,0.83714,0.80342],[0.09532,0.84455,0.79299],[0.09377,0.85175,0.78264],[0.09287,0.85875,0.77240],[0.09267,0.86554,0
rtol = 1e-3

gc.collect()
# Out:
# 0

# %%
#clean copy to calculate Delta_f, if not using stored data:
nvals = np.array([0,2,4])

#mass ratio values used for Figure 2:
# ms_mchi_arr = np.array([1/30, 1/10, 1/3, 1, 3, 10, 30, 100])

#mass ratio values used for Figure 3:
ms_mchi_arr = np.array([1/100, 1, 100])
Delta_f_store = np.zeros([len(nvals), len(ms_mchi_arr), nu, ny])

break_loop = False
print("ms/mchi: ", np.around(ms_mchi_arr, 2) )
max_test_sum = np.zeros([len(nvals), len(ms_mchi_arr)])

for i, n in zip(range(len(nvals)) , nvals):
    for j, ms_mchi in zip(range(len(ms_mchi_arr)) , ms_mchi_arr):
        print('n=%i, ms_mchi = %0.3g, nu=%i, dlnu=%0.0e, umin=%0.0e, umax=%0.0e\nai_fac = %0.1e, af_fac = %0.1e, dlny = %0.1e'\
                    %(n, ms_mchi, nu,dlnu,umin,umax\
                      ,ai_fac,af_fac,dlny)
             )
        gc.collect()
        Mij, Gamma = get_Mij_and_Gamma_ij(n, ms_mchi, u_arr, dlnu)
        print(Mij.shape)
        if np.any(Mij) == None:
            print("Mij calculation failed::: breaking out of loop")
            break_loop = True
            break
        gc.collect()

        Delta_f, top10, top10_inds = get_Delta_f(n, ms_mchi
                                                  , u_arr, dlnu 
                                                  , Mij
                                                  , y_arr, dlny
                                                  , rtol = 1e-3, atol = 0
                                                  , collisions_on = 1) # 1: DM-b collisions are allowed by default; 0: only redshifting, no DM-b collisions
        max_test_sum[i,j] = top10[-1]
        
        if np.any(top10>1e-9):
            print("largest 10 values of sum_j(\Delta_f_ij * du_j): \n"+str(top10))
            print("indices of largest 10 values of sum_j(\Delta_f_ij * du_j): \n"+str(top10_inds))
        Delta_f_store[i,j] = Delta_f
    gc.collect()
# Out:
# ms/mchi:  [1.e-02 1.e+00 1.e+02]
# n=0, ms_mchi = 0.01, nu=1272, dlnu=1e-02, umin=1e-06, umax=8e+00
# ai_fac = 1.0e-02, af_fac = 1.0e+03, dlny = 1.0e-02
# (1272, 1272)
# starting ODE solver:
# $\Delta f$ calculated.
# Run time: 0 min, OR 2.354E+01 sec
# Delta_f passed tests
# n=0, ms_mchi = 1, nu=1272, dlnu=1e-02, umin=1e-06, umax=8e+00
# ai_fac = 1.0e-02, af_fac = 1.0e+03, dlny = 1.0e-02
# (1272, 1272)
# starting ODE solver:
# $\Delta f$ calculated.
# Run time: 0 min, OR 2.056E+01 sec
# Delta_f passed tests
# largest 10 values of sum_j(\Delta_f_ij * du_j):
# [1.56799054e-09 1.62043264e-09 1.68956484e-09 1.76144873e-09
#  1.79231745e-09 1.79881149e-09 1.79894132e-09 1.80076662e-09
#  1.85693255e-09 1.92703281e-09]
# indices of largest 10 values of sum_j(\Delta_f_ij * du_j):
# [1142 1143 1144 1145 1146 1148 1147 1149 1150 1151]
# n=0, ms_mchi = 100, nu=1272, dlnu=1e-02, umin=1e-06, umax=8e+00
# ai_fac = 1.0e-02, af_fac = 1.0e+03, dlny = 1.0e-02
# (1272, 1272)
# starting ODE solver:
# ...

# %%
"""FOR SAVING DATA AFTER CALCULATION:::"""
# np.save('Delta_f_matrices/testFIG3_Delta_f_n=024_msmchi=1e-2_1e0_1e2_aifac=%0.3g_affac=%0.3g_dlny=%0.3g_umin=%0.3g_umax=%0.3g_dlnu=%0.3g.npy'%(ai_fac,af_fac,dlny,umin,umax,dlnu),Delta_f_store)
# np.save('Delta_f_matrices/testFIG2_Delta_f_n=024_msmchi=3.3e-2_1e-1_3.3e-1_1e0_3e0_1e1_3e1_1e2_aifac=%0.3g_affac=%0.3g_dlna=%0.3g_umin=%0.3g_umax=%0.3g_dlnu=%0.3g.npy'%(ai_fac,af_fac,dlny,umin,umax,dlnu),Delta_f_store)

"""FOR LOADING DATA TO MAKE FIGURES:::"""
#Fig 2 data:
Delta_f_store_fig2 = np.load('Delta_f_matrices/FIG2_Delta_f_n=024_msmchi=3.3e-2_1e-1_3.3e-1_1e0_3e0_1e1_3e1_1e2_aifac=%0.3g_affac=%0.3g_dlna=%0.3g_umin=%0.3g_umax=%0.3g_dlnu=%0.3g.npy'%(ai_fac,af_fac,dlny,umin,umax,dlnu))
# Fig 3 data:
Delta_f_store_fig3 = np.load('Delta_f_matrices/FIG3_Delta_f_n=024_msmchi=1e-2_1e0_1e2_aifac=%0.3g_affac=%0.3g_dlna=%0.3g_umin=%0.3g_umax=%0.3g_dlnu=%0.3g.npy'%(ai_fac,af_fac,dlny,umin,umax,dlnu))

# %% [markdown]
# ## figure of $\frac{|\Delta Q|}{Q}\left(a\right)$ for all $n$, all $\ m_\chi/m_s$ ratios

# %% [markdown]
# ### final figure 2 in paper:

# %%
#clean copy for fig 2
nvals = np.array([0,2,4])
du_arr = dlnu * u_arr
dlnxFP = 2e-3 #rescaled velocity spacing used in FP code
ms_mchi_arr = np.array([1/30, 1/10, 1/3, 1, 3, 10, 30, 100])
msmchi_labels = [r'$30^{-1}$', r'$10^{-1}$', r'$3^{-1}$', '1', '3', '10', '30', '100' ]
clrs = ['#ece2f0',(210/256,197/256,216/256),'#d0d1e6','#a6bddb','#67a9cf','#3690c0','#02818a','#016450']
fig, ax = plt.subplots(len(nvals), 2, figsize= [3.75*2,4*len(nvals)],
                       squeeze = True, sharex = 'row')

Q_FP_tab = np.load('FIG2_QFP_n=024_mchims=3e1_1e1_3e0_1e0_3.3e-1_1e-1_3.3e-2_1e-2_dlnxFP=%0.3g.npy'%(dlnxFP), allow_pickle=False)

for i,n in zip(range(len(nvals))[:], nvals):
    ax0, ax1 = ax[i,0], ax[i,1] 
    print("n = %i"%n)
    TEXTS0, TEXTS1 = [], []
    for j,ms_mchi in zip(range(len(ms_mchi_arr)), ms_mchi_arr):
        Q_MB_arr, _ = get_dimensionless_Q_and_X_MB(n, ms_mchi, y_arr, dlny)
        
        this_Delta_f = Delta_f_store_fig2[i,j]
        Q_sim_arr = get_dimensionless_heating_rate_exact(n, ms_mchi, this_Delta_f
                                                         , y_arr, dlny
                                                         , u_arr, dlnu)

        Q_FP = Q_FP_tab[i,j,:len(y_arr)]
        frac_diff_Q_QMB = (Q_MB_arr - Q_sim_arr)/Q_sim_arr 
        frac_diff_Q_QFP = (Q_FP - Q_sim_arr)/Q_sim_arr 
        
        """plot specs hereafter:"""
        clr = clrs[j]
        ax0.plot(y_arr, frac_diff_Q_QMB, lw = 1., c=clr,
                 label = msmchi_labels[j]) 
        ax1.plot(y_arr, frac_diff_Q_QFP, lw = 1.,  c=clr)
        ax1.tick_params(axis="y",direction="in", right= True, left = True, 
                                            pad=2,labelleft = False, labelright= True)#            
        ax0.set_xscale('log')
        ax1.set_xscale('log')
        
        #code for auto-adjustment of labels:
        peak_ind1 = np.argmax(frac_diff_Q_QFP)
        xx1 = y_arr[peak_ind1]
        yy1 = frac_diff_Q_QFP[peak_ind1]
        text1 = msmchi_labels[j] if ms_mchi != 10 else r'$m_s/m_\chi =$'+msmchi_labels[j]

        clr1 = clrs[j] 
        TEXTS1.append(ax1.text(xx1, yy1, text1, color=clr1, ha = 'left', 
                              va = 'center', fontsize=8, fontname="Times New Roman"))
        adjust_text(TEXTS1,
                    expand_points=(1.05, 1),ax=ax1)

        ax0.annotate(r'$n=%i$'%n,(0.05,0.9), xycoords = 'axes fraction', fontsize = 12)
        ax1.annotate(r'$n=%i$'%n,(0.05,0.9),  xycoords = 'axes fraction', fontsize = 12)
        ax0.set_xlim(2e-2,af_fac)# (9e-3, 1e0) #
        ax0.set_ylabel(r'$\left(\dot{\mathcal Q}^{\rm MB} - \dot{\mathcal Q}^{\rm ex}\right)\left/\dot{\mathcal Q}^{\rm ex}\right.$ ',
                       labelpad=1.6, fontsize = 12)
        ax1.set_ylabel(r'$\left(\dot{\mathcal Q}^{\rm FP} - \dot{\mathcal Q}^{\rm ex}\right)\left/\dot{\mathcal Q}^{\rm ex}\right.$ '
                       ,labelpad=2.2, fontsize = 12)
        if i == 2: 
            ax0.set_xlabel(r'$a\left/a_{\chi b}\right.$',fontsize= 12)
            ax1.set_xlabel(r'$a\left/a_{\chi b}\right.$',fontsize= 12)
    ax0.axvline(x = 1, c = 'k', ls = ':', lw = 0.25)
    ax0.axhline(y = 0, c = 'k', ls = ':', lw = 0.25)
    ax1.axvline(x = 1, c = 'k', ls = ':', lw = 0.25)
    ax1.axhline(y = 0, c = 'k', ls = ':', lw = 0.25)
    print("~~~~~~~~~~~~~~~~~~~~~")
ax[0,0].set_title('MB vs. exact', fontsize = 12)
handles, labels = ax[1,0].get_legend_handles_labels()
ax[1,0].legend(handles[::-1], labels[::-1], fontsize = 8, frameon = False, title=r'$m_s/m_\chi$')
ax[0,1].set_title('FP vs. exact', fontsize = 12)

plt.subplots_adjust(hspace = 0.09, wspace = 0.14)

"""save figure:"""
# filepath = '/Users/suroor/Documents/Graduate School/DM-baryon scattering/Research_Projects/exact_CBE_Fokker_Planck_accuracy(Jan2020-May2022)/paper_draft_figures/'
# filename = 'colorblind_frac_diff_QMB_QFP_n=024_mchims=3e1_1e1_3e0_1e0_3.3e-1_1e-1_3.3e-2_1e-2'
# plt.savefig(filepath+filename+'.pdf',bbox_inches='tight')
# Out:
# n = 0
# ~~~~~~~~~~~~~~~~~~~~~
# n = 2
# ~~~~~~~~~~~~~~~~~~~~~
# n = 4
# ~~~~~~~~~~~~~~~~~~~~~

# %% [markdown]
# ### Figure 3 in paper:
# ### deviations between f_FP(T_\chi) and f_ex(T_\chi):

# %%
#clean copy for fig 3

"""execute the line below ONLY if Delta_f_store 
was calculated and NOT read in from data file:"""
Delta_f_store_fig3 = Delta_f_store
""""""
ms = mp
nvals = np.array([0,2,4])
n_inds = np.array([0,1,2])  #indices corresponding to mchi values selected from nvals
ms_mchi_arr = np.array([1e-2, 1, 100])
ms_mchi_inds = np.array([0,1,2]) #indices corresponding to mchi values selected from ms_mchi_array
dlnx = 2e-3

feq = 4*np.pi * u_arr**2/(2*np.pi)**(3/2) \
                                        * np.exp(-u_arr**2/2)
#load FP data:
fFP_Tchi_tabtab = np.load('FIG3_(fFP_Tchi)_n=024_msmchi=1e-2_1e0_1e2_dlnx=%0.3g_dlnu=%0.3g_dlny=%0.3g.npy'\
                          %(dlnx,dlnu,dlny))
f = plt.figure(figsize= [5.5*len(ms_mchi_arr),6*len(nvals)])
plt.subplots_adjust(hspace=0.025, wspace = 0.025)
gs0 = gspec.GridSpec(len(nvals), len(ms_mchi_arr), figure=f)
fontsize = 15

npts = 20 #num of delta f curves in one panel
ylims = [0.35,0.16,0.115]

for (n, i) in zip(nvals[n_inds], n_inds ):
    gc.collect()

    for(ms_mchi, j) in zip(ms_mchi_arr[ms_mchi_inds],  ms_mchi_inds):
        print(n,ms_mchi)
        Delta_f = Delta_f_store_fig3[i,j]
        _, XMB = get_dimensionless_Q_and_X_MB(n, ms_mchi, y_arr, dlny) #dim = [y_arr]
    
        gsij = gspec.GridSpecFromSubplotSpec(4, 1, subplot_spec = gs0[i,j], hspace = .0)
        ax0 = f.add_subplot(gsij[:-1, :])
        ax0.set_ylim(-0.03,0.7)
        ax1 = f.add_subplot(gsij[-1, :], sharex = ax0)
        ax1.set_ylim(-ylims[i],ylims[i])
        clrs = iter(np.linspace(0.1,1,npts))
        
        feq_Tchi_tab = 4*np.pi / XMB[None,:] * u_arr[:,None]**2 \
                            / (2*np.pi)**(3/2) * np.exp(- u_arr[:,None]**2/XMB[None,:]/2)    #feq as a function of np.sqrt(mchi/"Tchi_MB")*v
        fFP_Tchi_tab = fFP_Tchi_tabtab[i,j] #dim = [ny, nu]
        f_tab = feq[:,None] + Delta_f # dim: [nu, nsteps]
        f_Tchi_tab = f_tab * np.sqrt(XMB[None,:]) #dim = [nu, nsteps]
        Delta_f_fFP_Tchi_tab = fFP_Tchi_tab - f_Tchi_tab.T
        
        """plot specs hereafter:"""
        for k in np.linspace(0, len(y_arr)-1, npts).astype(int):
            clr = next(clrs)
            ax0.plot( u_arr/np.sqrt(XMB[k]), f_Tchi_tab[:,k], c = plt.cm.BuPu(clr), lw = 1) 
            plt.setp(ax0.get_xticklabels(), visible=False)
            ax1.plot(u_arr/np.sqrt(XMB[k]), Delta_f_fFP_Tchi_tab[k], c = plt.cm.PuRd(clr), lw = 1)
            
        if n == nvals[0]: #top row
            ax0.set_title(r'$m_s/m_\chi = 10^{%i}$'%(int(np.log10(ms_mchi))), fontsize = fontsize)
            if j == ms_mchi_inds[0]: #top row, leftmost panel
                ax0.text(0.955, 0.9, r' $n=%i$, '%(n)+\
                             r' $m_s/m_\chi = 10^{%i}$'%(int(np.log10(ms_mchi)))
                                 , transform=ax0.transAxes , va='bottom', ha = 'right',fontsize = fontsize)
            else: #top row, remaining panels
                ax0.text(0.955, 0.9, r'${n=%i}$, '%(n) +\
                             r' $m_s/m_\chi = 10^{%i}$'%(int(np.log10(ms_mchi)))
                             , transform=ax0.transAxes , va='bottom', ha = 'right',fontsize = fontsize)
        else: #middle or bottom row
            if ms_mchi ==ms_mchi_arr[0]: #middle or bottom row, left panel
                ax0.text(0.955, 0.9, r' $n=%i$, '%(n)+\
                             r' $m_s/m_\chi = 10^{%i}$'%(int(np.log10(ms_mchi)))
                                 , transform=ax0.transAxes , va='bottom', ha = 'right',fontsize = fontsize)
            else:#middle or bottom row, remaining panels
                ax0.text(0.955, 0.9, r'${n=%s}$, '%str(n)+\
                             r' $m_s/m_\chi = 10^{%i}$'%(int(np.log10(ms_mchi)))
                                 , transform=ax0.transAxes , va='bottom', ha = 'right',fontsize = fontsize)
                
        if i!=len(n_inds)-1:
            plt.setp(ax1.get_xticklabels(), visible=False)
        if j!=0:
            plt.setp(ax0.get_yticklabels(), visible=False)
            plt.setp(ax1.get_yticklabels(), visible=False)

        ax0.plot(u_arr/np.sqrt(XMB[k]), feq_Tchi_tab[:,k], c='k', lw =2.2, ls = ':',
              label = r'$\left.\overline{f}_\chi^{\mathrm{\,MB}}\right|_{T_\chi^\mathrm{MB}}$')
        if ms_mchi ==ms_mchi_arr[0]:  
            ax0.set_ylabel(r'$\overline{f}_\chi^{\mathrm{\ ex}}$',fontsize = fontsize)
            ax1.set_ylabel(r'$\overline{f}_\chi^{\mathrm{\ FP}} - \overline{f}_\chi^{\mathrm{\ ex}}$',fontsize = fontsize)

        ax0.set_xlim(0,5.5)
        ax0.axhline(y = 0, lw = 1, c = 'k', alpha = 0.25)
        ax0.legend(loc = 'lower right', edgecolor='none', frameon = False,
                   bbox_to_anchor=(0.955, 0.2),fontsize = fontsize)

        if n == nvals[-1]:
            ax1.set_xlabel(r'$\sqrt{m_\chi\left/T^{\rm MB}_\chi\right.}\,v$',fontsize = fontsize)

"""save figure:"""
# filepath = ''
# filename = 'rev_fex(TchiMB)_fFP-fex_n=024_mchims=1e-2_1e-0_1e2_dlnxFP=%0.3g'%dlnx
# plt.savefig(filepath+filename+'.pdf',bbox_inches='tight')
plt.show()
# Out:
# 0 0.01
# 0 1.0
# 0 100.0
# 2 0.01
# 2 1.0
# 2 100.0
